# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 57
#      54 layer_groups = list(province_parents.values())  # List of FeatureGroups for each province
#      56 # Add GroupedLayerControl
# ---> 57 GroupedLayerControl(
#      58     groups=group_names,  # List of group names (provinces)
#      59     layers=layer_groups,  # Corresponding layers
#      60     collapsed=False
#      61 ).add_to(m)
#      63 # Save the map to an HTML file
#      64 m.save('canadian_aerodromes_map.html')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\folium\plugins\groupedlayercontrol.py:74, in GroupedLayerControl.__init__(self, groups, exclusive_groups, **kwargs)
#      72 self.options = remove_empty(**kwargs)
#      73 if exclusive_groups:
# ---> 74     self.options["exclusiveGroups"] = list(groups.keys())
#      75 self.layers_untoggle = set()
# ...
